# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('inventory.xlsx', 'Columns', index_col=None)
data.to_csv('inv.csv', encoding='utf-8', index=False)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#      Unnamed: 0     Unnamed: 1  \
# 0      From Top       Column 1
# 1        Bottle           Year
# 2            No  Vintage or NV
# 3             1            NaN
# 4             2            NaN
# 5             3            NaN
# 6             4            NaN
# 7             5            NaN
# 8             6            NaN
# 9             7            NaN
# 10            8            NaN
# 11            9            NaN
# 12           10            NaN
# 13           11            NaN
# 14           12            NaN
# 15           13            NaN
# 16           14            NaN
# 17          NaN            NaN
# 18           15            NaN
# 19           16            NaN
# 20           17            NaN
# 21           18            NaN
# 22           19            NaN
# 23           20            NaN
# 24           21            NaN
# 25           22            NaN
# 26           23            NaN
# 27           24            NaN
# 28           25            NaN
# ...
